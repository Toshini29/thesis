# %%
import os
import sys
sys.path.insert(0, os.path.abspath('') + '/src')

# %%
from karibdis.Application import JupyterApplication

# %%
JupyterApplication().run()
# Out:
# JupyterApplication(children=(Tab(children=(VBox(children=(Card(children=[CardTitle(children=['Start New Import…
